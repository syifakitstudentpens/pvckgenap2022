# %% [markdown]
# <a href="https://colab.research.google.com/github/AjiArdiansyah/PCVK_Genap_2022/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

#Accesing My Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
img = cv.imread('/content/drive/My Drive/PCVK/Week2/kitten01.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB) #konveksi chanel BGR -> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/My Drive/PCVK/Week2/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#simpan File image
#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10)) #ubah - ubah ukuran
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) # nilai 2 untuk menunjukan bahwa tiap titik dibuat 3 chanel yang mewakili R, G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %%
#TUGAS
# nomor 1
# Red-Green
img_rg = cv.imread('/content/drive/My Drive/PCVK/Week2/kitten01.jpg',cv.IMREAD_GRAYSCALE)
plt.imshow(img_rg, cmap='RdYlGn'),plt.title("Red-Green")
#plt.imshow(img5)
# Out:
# (<matplotlib.image.AxesImage at 0x7ff143a4d4d0>, Text(0.5, 1.0, 'Red-Green'))

# %%
# Green-Blue
img_rg = cv.imread('/content/drive/My Drive/PCVK/Week2/kitten01.jpg',cv.IMREAD_GRAYSCALE)
#img_rg [:,:,2] = 0
plt.imshow(img_rg)

# %%
# Green-Blue
img_gb = img
img_gb[:,:,0] = 0
plt.imshow(img_gb)

# %%
# 2. Tampilkan image baris ke 10-100, kolom 10-100!
img_gb = img[10:100,10:100]
plt.imshow(img_gb)

# %%
# 3. Tampilkan image baris ke 5-30, semua kolom, channel Green saja!
# Channel Green
img_tg3 = cv.imread('/content/drive/My Drive/PCVK/Week2/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_tg3[5:30], cmap='Greens')

# %%
# 4. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image. disarankan menggunakan bilangan acak/random!
img_ktk = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img_ktk, pt1=(300,300), pt2=(40,170), color=(0,255,255), thickness=10)
cv.rectangle(img_ktk, pt1=(500,150), pt2=(350,200), color=(0,255,0),thickness=10)
cv.rectangle(img_ktk, pt1=(400,400), pt2=(500,300), color=(255,255,255),thickness=10)
cv.rectangle(img_ktk, pt1=(100,500), pt2=(300,400), color=(255,0,0),thickness=10)
cv.rectangle(img_ktk, pt1=(400,700), pt2=(500,650), color=(0,0,255),thickness=10)
plt.imshow(img_ktk)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#simpan File image
#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(7,7)) #ubah - ubah ukuran
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
# Berdasarkan praktikum bagian 3 dan 4 kerjakan beberapa tugas berikut :
# 6. Buat rectangle dan circle pada bagian wajah dari image kitten!
img_f = cv.imread('/content/drive/My Drive/PCVK/Week2/kitten01.jpg')
plt.imshow(img_f)

# %%
img_f = cv.imread('/content/drive/My Drive/PCVK/Week2/kitten01.jpg')
plt.imshow(img_f)
cv.rectangle(img_f,pt1=(150,360),pt2=(400,150),color=(0,0,255),thickness=15)
plt.imshow(img_f)

# %%
cv.circle(img_f,center=(280,250),radius=120,color=(255,0,0),thickness=8)
plt.imshow(img_f)

# %%
# 7. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten01.jpg!
img_f = cv.imread('/content/drive/My Drive/PCVK/Week2/kitten01.jpg')
img3 = cv.cvtColor(img_f,cv.COLOR_BGR2RGB)
cv.rectangle(img3,pt1=(100,500),pt2=(0,600),color=(0,0,255),thickness=15)
plt.imshow(img3)
